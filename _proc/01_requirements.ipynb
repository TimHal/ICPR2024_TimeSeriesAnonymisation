# %% [raw]
# ---
# description: Preparing your environment.
# output-file: requirements.html
# title: Requirements
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/TimHal/ICPR2024_TimeSeriesAnonymisation/blob/main/ICPR2024_TimeSeriesAnonymisation/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()
