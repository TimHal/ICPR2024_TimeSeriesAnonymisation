# %% [raw]
# ---
# description: AnonGan - Anonymisation for Time-Series Human Activity Data
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# ### foo
#
# >      foo ()
